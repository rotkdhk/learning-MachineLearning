# %% [markdown]
# ### Before going to scaling part let's execute function for CostFunction, Gradient
#
# **Cost function (Mean Squared Error, linear regression)**
#
# $$J(w,b) = \frac{1}{2m} \sum_{i=1}^{m} \left( f_{w,b}(x^{(i)}) - y^{(i)} \right)^2$$
#
# where $f_{w,b}(x^{(i)}) = wx^{(i)} + b$, and $m$ is the number of training examples.
#
# **Gradients (dw, db)**
#
# $$\frac{\partial J}{\partial w} = \frac{1}{m} \sum_{i=1}^{m} \left( f_{w,b}(x^{(i)}) - y^{(i)} \right) x^{(i)}$$
#
# $$\frac{\partial J}{\partial b} = \frac{1}{m} \sum_{i=1}^{m} \left( f_{w,b}(x^{(i)}) - y^{(i)} \right)$$
#
# Update step:
#
# $$w := w - \alpha \frac{\partial J}{\partial w}, \qquad b := b - \alpha \frac{\partial J}{\partial b}$$

# %%
def compute_cost(x,y,w,b):
    if(len(x.shape)>1):
        m,n = x.shape #m samples, n features
    else:
        m = len(x)

    cost = 0
    for i in range(m):
        error = np.dot(x[i],w)+b-y[i] #dot product
        cost = cost+error**2
    return cost/(2*m)

def gradient(x,y,w,b):
    if(len(x.shape)>1):
        m,n = x.shape #m samples, n features
        dw = np.zeros((n,))
    else:
        m = len(x)
        dw = np.zeros((1,))
    db= 0.

    for i in range(m):
        error = np.dot(w,x[i])+b-y[i] #dot product
        dw = dw+(error*x[i])
        db = db+error
    return dw/m,db/m

# %% [markdown]
# Let's take a dataset and compare how graphs, gradient descent, and cost functions look before and after data standardization.

# %%
import numpy as np

X_train = np.array([
    [952, 2, 1, 65],
    [1244, 3, 2, 64],
    [1947, 3, 2, 17],
    [1725, 3, 2, 42],
    [1959, 3, 2, 15],
    [1314, 2, 1, 14],
    [864, 2, 1, 66],
    [1836, 3, 1, 40],
    [1026, 3, 1, 30],
    [3137, 3, 2, 13],
    [1580, 3, 2, 20],
    [1204, 3, 1, 12],
    [1553, 3, 2, 39],
    [1224, 3, 1, 64],
    [1090, 2, 1, 30]
])

y_train = np.array([271.5, 232, 509.8, 406, 452.5, 318.5, 240, 
                     414, 289.9, 705.4, 379.5, 279.6, 340, 
                     264.5, 251.5])

X_features = ['size(sqft)', 'bedrooms', 'floors', 'age']

# %% [markdown]
# Plot the diff features with output y_train

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 4, figsize=(12,3))
for i in range(len(X_features)):
    ax[i].scatter(X_train[:,i],y_train)
    ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("prices in 100$")
# Out:
# Text(0, 0.5, 'prices in 100$')

# %% [markdown]
# compute w,b and costfunction

# %%
alpha = 6.0e-7
w_r = np.zeros(X_train.shape[1])
b_r = 0.

for i in range(100000):
    if(i%100 == 0):
        print(f"Cost of {i} iteration is {compute_cost(X_train,y_train,w_r,b_r)}")
    dw,db = gradient(X_train,y_train,w_r,b_r)
    w_r = w_r-alpha*dw
    b_r = b_r-alpha*db
# Out:
# Cost of 0 iteration is 71336.76233333333
# Cost of 100 iteration is 502.0900135233585
# Cost of 200 iteration is 501.73871526061555
# Cost of 300 iteration is 501.4188212936006
# Cost of 400 iteration is 501.12751585463616
# Cost of 500 iteration is 500.8622356433146
# Cost of 600 iteration is 500.62064718978957
# Cost of 700 iteration is 500.40062624771303
# Cost of 800 iteration is 500.2002390348447
# Cost of 900 iteration is 500.0177251556657
# Cost of 1000 iteration is 499.8514820551835
# Cost of 1100 iteration is 499.7000508666425
# Cost of 1200 iteration is 499.5621035281475
# Cost of 1300 iteration is 499.43643105444994
# Cost of 1400 iteration is 499.3219328602966
# Cost of 1500 iteration is 499.21760704107226
# Cost of 1600 iteration is 499.12254152490533
# Cost of 1700 iteration is 499.03590601807934
# Cost of 1800 iteration is 498.95694467264804
# Cost of 1900 iteration is 498.88496941147883
# Cost of 2000 iteration is 498.8193538517896
# Cost of 2100 iteration is 498.75952777351137
# Cost of 2200 iteration is 498.7049720836272
# Cost of 2300 iteration is 498.65521423202296
# Cost of 2400 iteration is 498.6098240383571
# Cost of 2500 iteration is 498.5684098931033
# Cost of 2600 iteration is 498.5306152992173
# Cost of 2700 iteration is 498.4961157238804
# Cost of 2800 iteration is 498.4646157325255
# Cost of 2900 iteration is 498.4358463798297
# Cost of 3000 iteration is 498.4095628346369
# Cost of 3100 iteration is 498.3855422178336
# Cost of 3200 iteration is 498.36358163408835
# Cost of 3300 iteration is 498.3434963800609
# Cost of 3400 iteration is 498.3251183132791
# Cost of 3500 iteration is 498.30829436725367
# Cost of 3600 iteration is 498.2928851997383
# Cost of 3700 iteration is 498.27876396218744
# Cost of 3800 iteration is 498.2658151795431
# Cost of 3900 iteration is 498.25393373047166
# Cost of 4000 iteration is 498.2430239190223
# Cost of 4100 iteration is 498.23299862953144
# Cost of 4200 iteration is 498.22377855730014
# Cost of 4300 iteration is 498.21529150824097
# Cost of 4400 iteration is 498.20747176133216
# Cost of 4500 iteration is 498.2002594882277
# Cost of 4600 iteration is 498.19360022490906
# Cost of 4700 iteration is 498.18744439070787
# Cost of 4800 iteration is 498.1817468504558
# Cost of 4900 iteration is 498.1764665158936
# Cost of 5000 iteration is 498.17156598281423
# Cost of 5100 iteration is 498.1670112007488
# Cost of 5200 iteration is 498.16277117225525
# Cost of 5300 iteration is 498.1588176791868
# Cost of 5400 iteration is 498.1551250334904
# Cost of 5500 iteration is 498.15166985035347
# Cost of 5600 iteration is 498.1484308416922
# Cost of 5700 iteration is 498.14538862815317
# Cost of 5800 iteration is 498.142525567975
# Cost of 5900 iteration is 498.13982560119103
# Cost of 6000 iteration is 498.137274107801
# Cost of 6100 iteration is 498.1348577786652
# Cost of 6200 iteration is 498.132564497965
# Cost of 6300 iteration is 498.130383236212
# Cost of 6400 iteration is 498.1283039528417
# Cost of 6500 iteration is 498.1263175075462
# Cost of 6600 iteration is 498.12441557955503
# Cost of 6700 iteration is 498.1225905941567
# Cost of 6800 iteration is 498.1208356557998
# Cost of 6900 iteration is 498.1191444872049
# Cost of 7000 iteration is 498.11751137392275
# Cost of 7100 iteration is 498.1159311138739
# Cost of 7200 iteration is 498.1143989714071
# Cost of 7300 iteration is 498.11291063548026
# Cost of 7400 iteration is 498.111462181585
# Cost of 7500 iteration is 498.1100500370932
# Cost of 7600 iteration is 498.10867094970666
# Cost of 7700 iteration is 498.1073219587328
# Cost of 7800 iteration is 498.1060003689409
# Cost of 7900 iteration is 498.10470372676014
# Cost of 8000 iteration is 498.1034297986118
# Cost of 8100 iteration is 498.1021765511823
# Cost of 8200 iteration is 498.1009421334715
# Cost of 8300 iteration is 498.09972486044103
# Cost of 8400 iteration is 498.0985231981369
# Cost of 8500 iteration is 498.0973357501426
# Cost of 8600 iteration is 498.09616124524825
# Cost of 8700 iteration is 498.0949985262203
# Cost of 8800 iteration is 498.093846539586
# Cost of 8900 iteration is 498.09270432633053
# Cost of 9000 iteration is 498.09157101342345
# Cost of 9100 iteration is 498.09044580611294
# Cost of 9200 iteration is 498.08932798090706
# Cost of 9300 iteration is 498.0882168791813
# Cost of 9400 iteration is 498.087111901366
# Cost of 9500 iteration is 498.0860125016507
# Cost of 9600 iteration is 498.0849181831603
# Cost of 9700 iteration is 498.0838284935746
# Cost of 9800 iteration is 498.0827430211246
# Cost of 9900 iteration is 498.08166139096465
# Cost of 10000 iteration is 498.08058326185596
# Cost of 10100 iteration is 498.07950832315794
# Cost of 10200 iteration is 498.07843629208105
# Cost of 10300 iteration is 498.077366911191
# Cost of 10400 iteration is 498.0762999461353
# Cost of 10500 iteration is 498.07523518357624
# Cost of 10600 iteration is 498.07417242929984
# Cost of 10700 iteration is 498.07311150651
# Cost of 10800 iteration is 498.07205225425895
# Cost of 10900 iteration is 498.0709945260324
# Cost of 11000 iteration is 498.06993818845035
# Cost of 11100 iteration is 498.0688831200936
# Cost of 11200 iteration is 498.0678292104277
# Cost of 11300 iteration is 498.06677635883005
# Cost of 11400 iteration is 498.06572447370024
# Cost of 11500 iteration is 498.0646734716492
# Cost of 11600 iteration is 498.0636232767652
# Cost of 11700 iteration is 498.0625738199447
# Cost of 11800 iteration is 498.0615250382769
# Cost of 11900 iteration is 498.0604768744932
# Cost of 12000 iteration is 498.05942927645964
# Cost of 12100 iteration is 498.0583821967164
# Cost of 12200 iteration is 498.0573355920575
# Cost of 12300 iteration is 498.05628942315366
# Cost of 12400 iteration is 498.0552436541994
# Cost of 12500 iteration is 498.0541982526
# Cost of 12600 iteration is 498.0531531886832
# Cost of 12700 iteration is 498.0521084354376
# Cost of 12800 iteration is 498.0510639682727
# Cost of 12900 iteration is 498.05001976480247
# Cost of 13000 iteration is 498.04897580465
# Cost of 13100 iteration is 498.047932069263
# Cost of 13200 iteration is 498.04688854175316
# Cost of 13300 iteration is 498.04584520674564
# Cost of 13400 iteration is 498.04480205024566
# Cost of 13500 iteration is 498.04375905951076
# Cost of 13600 iteration is 498.04271622294357
# Cost of 13700 iteration is 498.0416735299853
# Cost of 13800 iteration is 498.0406309710215
# Cost of 13900 iteration is 498.0395885373033
# Cost of 14000 iteration is 498.038546220863
# Cost of 14100 iteration is 498.0375040144485
# Cost of 14200 iteration is 498.0364619114594
# Cost of 14300 iteration is 498.0354199058844
# Cost of 14400 iteration is 498.03437799225145
# Cost of 14500 iteration is 498.0333361655793
# Cost of 14600 iteration is 498.03229442133505
# Cost of 14700 iteration is 498.0312527553884
# Cost of 14800 iteration is 498.0302111639825
# Cost of 14900 iteration is 498.0291696436954
# Cost of 15000 iteration is 498.02812819141235
# Cost of 15100 iteration is 498.02708680429765
# Cost of 15200 iteration is 498.0260454797701
# Cost of 15300 iteration is 498.0250042154786
# Cost of 15400 iteration is 498.0239630092843
# Cost of 15500 iteration is 498.0229218592386
# Cost of 15600 iteration is 498.02188076356947
# Cost of 15700 iteration is 498.02083972066055
# Cost of 15800 iteration is 498.01979872904246
# Cost of 15900 iteration is 498.0187577873766
# Cost of 16000 iteration is 498.0177168944449
# Cost of 16100 iteration is 498.0166760491373
# Cost of 16200 iteration is 498.0156352504448
# Cost of 16300 iteration is 498.0145944974467
# Cost of 16400 iteration is 498.01355378930685
# Cost of 16500 iteration is 498.0125131252613
# Cost of 16600 iteration is 498.01147250461656
# Cost of 16700 iteration is 498.0104319267397
# Cost of 16800 iteration is 498.0093913910569
# Cost of 16900 iteration is 498.00835089704225
# Cost of 17000 iteration is 498.00731044421985
# Cost of 17100 iteration is 498.0062700321534
# Cost of 17200 iteration is 498.0052296604489
# Cost of 17300 iteration is 498.0041893287434
# Cost of 17400 iteration is 498.0031490367111
# Cost of 17500 iteration is 498.0021087840516
# Cost of 17600 iteration is 498.00106857049184
# Cost of 17700 iteration is 498.0000283957855
# Cost of 17800 iteration is 497.9989882597061
# Cost of 17900 iteration is 497.9979481620464
# Cost of 18000 iteration is 497.99690810261984
# Cost of 18100 iteration is 497.9958680812554
# Cost of 18200 iteration is 497.9948280977969
# Cost of 18300 iteration is 497.99378815210304
# Cost of 18400 iteration is 497.99274824404347
# Cost of 18500 iteration is 497.99170837350124
# Cost of 18600 iteration is 497.99066854036846
# Cost of 18700 iteration is 497.9896287445467
# Cost of 18800 iteration is 497.98858898594716
# Cost of 18900 iteration is 497.98754926448856
# Cost of 19000 iteration is 497.9865095800961
# Cost of 19100 iteration is 497.9854699327005
# Cost of 19200 iteration is 497.9844303222423
# Cost of 19300 iteration is 497.9833907486639
# Cost of 19400 iteration is 497.98235121191334
# Cost of 19500 iteration is 497.98131171194376
# Cost of 19600 iteration is 497.98027224871214
# Cost of 19700 iteration is 497.97923282217926
# Cost of 19800 iteration is 497.97819343230947
# Cost of 19900 iteration is 497.9771540790682
# Cost of 20000 iteration is 497.97611476242747
# Cost of 20100 iteration is 497.97507548235836
# Cost of 20200 iteration is 497.97403623883565
# Cost of 20300 iteration is 497.9729970318368
# Cost of 20400 iteration is 497.97195786134057
# Cost of 20500 iteration is 497.9709187273265
# Cost of 20600 iteration is 497.96987962977823
# Cost of 20700 iteration is 497.96884056867856
# Cost of 20800 iteration is 497.9678015440122
# Cost of 20900 iteration is 497.9667625557653
# Cost of 21000 iteration is 497.9657236039259
# Cost of 21100 iteration is 497.9646846884798
# Cost of 21200 iteration is 497.96364580941975
# Cost of 21300 iteration is 497.9626069667317
# Cost of 21400 iteration is 497.96156816040946
# Cost of 21500 iteration is 497.9605293904428
# Cost of 21600 iteration is 497.95949065682464
# Cost of 21700 iteration is 497.95845195954604
# Cost of 21800 iteration is 497.95741329860175
# Cost of 21900 iteration is 497.9563746739836
# Cost of 22000 iteration is 497.95533608568684
# Cost of 22100 iteration is 497.9542975337061
# Cost of 22200 iteration is 497.95325901803494
# Cost of 22300 iteration is 497.95222053866803
# Cost of 22400 iteration is 497.95118209560246
# Cost of 22500 iteration is 497.95014368883216
# Cost of 22600 iteration is 497.9491053183537
# Cost of 22700 iteration is 497.94806698416335
# Cost of 22800 iteration is 497.9470286862567
# Cost of 22900 iteration is 497.9459904246307
# Cost of 23000 iteration is 497.944952199281
# Cost of 23100 iteration is 497.94391401020573
# Cost of 23200 iteration is 497.9428758574014
# Cost of 23300 iteration is 497.9418377408641
# Cost of 23400 iteration is 497.94079966059167
# Cost of 23500 iteration is 497.939761616581
# Cost of 23600 iteration is 497.93872360883023
# Cost of 23700 iteration is 497.93768563733573
# Cost of 23800 iteration is 497.9366477020959
# Cost of 23900 iteration is 497.9356098031074
# Cost of 24000 iteration is 497.9345719403684
# Cost of 24100 iteration is 497.9335341138769
# Cost of 24200 iteration is 497.9324963236292
# Cost of 24300 iteration is 497.9314585696251
# Cost of 24400 iteration is 497.9304208518609
# Cost of 24500 iteration is 497.92938317033565
# Cost of 24600 iteration is 497.92834552504644
# Cost of 24700 iteration is 497.92730791599047
# Cost of 24800 iteration is 497.92627034316786
# Cost of 24900 iteration is 497.9252328065752
# Cost of 25000 iteration is 497.9241953062103
# Cost of 25100 iteration is 497.9231578420717
# Cost of 25200 iteration is 497.9221204141578
# Cost of 25300 iteration is 497.9210830224661
# Cost of 25400 iteration is 497.9200456669945
# Cost of 25500 iteration is 497.9190083477416
# Cost of 25600 iteration is 497.91797106470614
# Cost of 25700 iteration is 497.91693381788485
# Cost of 25800 iteration is 497.91589660727766
# Cost of 25900 iteration is 497.9148594328813
# Cost of 26000 iteration is 497.9138222946942
# Cost of 26100 iteration is 497.9127851927151
# Cost of 26200 iteration is 497.9117481269415
# Cost of 26300 iteration is 497.91071109737214
# Cost of 26400 iteration is 497.9096741040053
# Cost of 26500 iteration is 497.9086371468389
# Cost of 26600 iteration is 497.90760022587085
# Cost of 26700 iteration is 497.9065633411007
# Cost of 26800 iteration is 497.9055264925252
# Cost of 26900 iteration is 497.9044896801431
# Cost of 27000 iteration is 497.90345290395345
# Cost of 27100 iteration is 497.90241616395355
# Cost of 27200 iteration is 497.90137946014113
# Cost of 27300 iteration is 497.90034279251637
# Cost of 27400 iteration is 497.89930616107534
# Cost of 27500 iteration is 497.89826956581845
# Cost of 27600 iteration is 497.89723300674166
# Cost of 27700 iteration is 497.8961964838455
# Cost of 27800 iteration is 497.89515999712677
# Cost of 27900 iteration is 497.894123546584
# Cost of 28000 iteration is 497.89308713221624
# Cost of 28100 iteration is 497.89205075402083
# Cost of 28200 iteration is 497.8910144119964
# Cost of 28300 iteration is 497.88997810614154
# Cost of 28400 iteration is 497.8889418364535
# Cost of 28500 iteration is 497.88790560293245
# Cost of 28600 iteration is 497.8868694055743
# Cost of 28700 iteration is 497.885833244379
# Cost of 28800 iteration is 497.8847971193447
# Cost of 28900 iteration is 497.8837610304689
# Cost of 29000 iteration is 497.88272497775034
# Cost of 29100 iteration is 497.88168896118765
# Cost of 29200 iteration is 497.8806529807782
# Cost of 29300 iteration is 497.8796170365213
# Cost of 29400 iteration is 497.87858112841485
# Cost of 29500 iteration is 497.87754525645744
# Cost of 29600 iteration is 497.8765094206461
# Cost of 29700 iteration is 497.8754736209806
# Cost of 29800 iteration is 497.87443785745893
# Cost of 29900 iteration is 497.8734021300786
# Cost of 30000 iteration is 497.87236643883875
# Cost of 30100 iteration is 497.8713307837364
# Cost of 30200 iteration is 497.87029516477224
# Cost of 30300 iteration is 497.8692595819427
# Cost of 30400 iteration is 497.86822403524553
# Cost of 30500 iteration is 497.8671885246809
# Cost of 30600 iteration is 497.8661530502456
# Cost of 30700 iteration is 497.86511761193884
# Cost of 30800 iteration is 497.8640822097588
# Cost of 30900 iteration is 497.8630468437026
# Cost of 31000 iteration is 497.8620115137695
# Cost of 31100 iteration is 497.8609762199591
# Cost of 31200 iteration is 497.85994096226756
# Cost of 31300 iteration is 497.85890574069384
# Cost of 31400 iteration is 497.8578705552365
# Cost of 31500 iteration is 497.85683540589343
# Cost of 31600 iteration is 497.85580029266373
# Cost of 31700 iteration is 497.85476521554415
# Cost of 31800 iteration is 497.8537301745351
# Cost of 31900 iteration is 497.852695169633
# Cost of 32000 iteration is 497.85166020083733
# Cost of 32100 iteration is 497.85062526814585
# Cost of 32200 iteration is 497.8495903715572
# Cost of 32300 iteration is 497.8485555110688
# Cost of 32400 iteration is 497.8475206866802
# Cost of 32500 iteration is 497.84648589838883
# Cost of 32600 iteration is 497.84545114619334
# Cost of 32700 iteration is 497.84441643009114
# Cost of 32800 iteration is 497.8433817500825
# Cost of 32900 iteration is 497.84234710616397
# Cost of 33000 iteration is 497.84131249833445
# Cost of 33100 iteration is 497.8402779265919
# Cost of 33200 iteration is 497.83924339093517
# Cost of 33300 iteration is 497.8382088913623
# Cost of 33400 iteration is 497.8371744278714
# Cost of 33500 iteration is 497.8361400004614
# Cost of 33600 iteration is 497.8351056091297
# Cost of 33700 iteration is 497.83407125387487
# Cost of 33800 iteration is 497.8330369346958
# Cost of 33900 iteration is 497.83200265158956
# Cost of 34000 iteration is 497.8309684045565
# Cost of 34100 iteration is 497.829934193593
# Cost of 34200 iteration is 497.82890001869725
# Cost of 34300 iteration is 497.82786587986965
# Cost of 34400 iteration is 497.8268317771057
# Cost of 34500 iteration is 497.8257977104061
# Cost of 34600 iteration is 497.8247636797685
# Cost of 34700 iteration is 497.82372968519
# Cost of 34800 iteration is 497.8226957266706
# Cost of 34900 iteration is 497.8216618042076
# Cost of 35000 iteration is 497.8206279177991
# Cost of 35100 iteration is 497.8195940674446
# Cost of 35200 iteration is 497.81856025314045
# Cost of 35300 iteration is 497.81752647488685
# Cost of 35400 iteration is 497.81649273268124
# Cost of 35500 iteration is 497.815459026521
# Cost of 35600 iteration is 497.8144253564067
# Cost of 35700 iteration is 497.81339172233436
# Cost of 35800 iteration is 497.8123581243041
# Cost of 35900 iteration is 497.81132456231364
# Cost of 36000 iteration is 497.81029103635996
# Cost of 36100 iteration is 497.80925754644323
# Cost of 36200 iteration is 497.80822409256103
# Cost of 36300 iteration is 497.80719067471165
# Cost of 36400 iteration is 497.80615729289224
# Cost of 36500 iteration is 497.8051239471037
# Cost of 36600 iteration is 497.80409063734146
# Cost of 36700 iteration is 497.80305736360594
# Cost of 36800 iteration is 497.80202412589483
# Cost of 36900 iteration is 497.80099092420573
# Cost of 37000 iteration is 497.79995775853826
# Cost of 37100 iteration is 497.7989246288886
# Cost of 37200 iteration is 497.7978915352573
# Cost of 37300 iteration is 497.7968584776417
# Cost of 37400 iteration is 497.79582545604063
# Cost of 37500 iteration is 497.79479247045066
# Cost of 37600 iteration is 497.79375952087224
# Cost of 37700 iteration is 497.7927266073028
# Cost of 37800 iteration is 497.79169372974053
# Cost of 37900 iteration is 497.79066088818325
# Cost of 38000 iteration is 497.7896280826307
# Cost of 38100 iteration is 497.78859531307927
# Cost of 38200 iteration is 497.787562579529
# Cost of 38300 iteration is 497.78652988197706
# Cost of 38400 iteration is 497.78549722042266
# Cost of 38500 iteration is 497.7844645948634
# Cost of 38600 iteration is 497.78343200529787
# Cost of 38700 iteration is 497.78239945172413
# Cost of 38800 iteration is 497.78136693414035
# Cost of 38900 iteration is 497.78033445254573
# Cost of 39000 iteration is 497.77930200693726
# Cost of 39100 iteration is 497.77826959731465
# Cost of 39200 iteration is 497.77723722367506
# Cost of 39300 iteration is 497.77620488601735
# Cost of 39400 iteration is 497.7751725843401
# Cost of 39500 iteration is 497.7741403186405
# Cost of 39600 iteration is 497.7731080889179
# Cost of 39700 iteration is 497.7720758951701
# Cost of 39800 iteration is 497.7710437373955
# Cost of 39900 iteration is 497.7700116155928
# Cost of 40000 iteration is 497.7689795297601
# Cost of 40100 iteration is 497.7679474798952
# Cost of 40200 iteration is 497.76691546599676
# Cost of 40300 iteration is 497.76588348806325
# Cost of 40400 iteration is 497.7648515460929
# Cost of 40500 iteration is 497.7638196400832
# Cost of 40600 iteration is 497.7627877700339
# Cost of 40700 iteration is 497.76175593594286
# Cost of 40800 iteration is 497.76072413780753
# Cost of 40900 iteration is 497.7596923756267
# Cost of 41000 iteration is 497.75866064939896
# Cost of 41100 iteration is 497.7576289591224
# Cost of 41200 iteration is 497.7565973047957
# Cost of 41300 iteration is 497.7555656864164
# Cost of 41400 iteration is 497.75453410398273
# Cost of 41500 iteration is 497.75350255749396
# Cost of 41600 iteration is 497.752471046948
# Cost of 41700 iteration is 497.7514395723428
# Cost of 41800 iteration is 497.7504081336774
# Cost of 41900 iteration is 497.74937673094934
# Cost of 42000 iteration is 497.74834536415705
# Cost of 42100 iteration is 497.7473140332986
# Cost of 42200 iteration is 497.7462827383728
# Cost of 42300 iteration is 497.7452514793785
# Cost of 42400 iteration is 497.74422025631264
# Cost of 42500 iteration is 497.7431890691754
# Cost of 42600 iteration is 497.7421579179619
# Cost of 42700 iteration is 497.74112680267393
# Cost of 42800 iteration is 497.740095723308
# Cost of 42900 iteration is 497.73906467986245
# Cost of 43000 iteration is 497.73803367233614
# Cost of 43100 iteration is 497.7370027007272
# Cost of 43200 iteration is 497.7359717650336
# Cost of 43300 iteration is 497.73494086525415
# Cost of 43400 iteration is 497.73391000138656
# Cost of 43500 iteration is 497.73287917342907
# Cost of 43600 iteration is 497.7318483813812
# Cost of 43700 iteration is 497.73081762524
# Cost of 43800 iteration is 497.7297869050034
# Cost of 43900 iteration is 497.7287562206714
# Cost of 44000 iteration is 497.7277255722414
# Cost of 44100 iteration is 497.7266949597118
# Cost of 44200 iteration is 497.7256643830804
# Cost of 44300 iteration is 497.7246338423461
# Cost of 44400 iteration is 497.72360333750714
# Cost of 44500 iteration is 497.72257286856166
# Cost of 44600 iteration is 497.7215424355073
# Cost of 44700 iteration is 497.7205120383442
# Cost of 44800 iteration is 497.7194816770687
# Cost of 44900 iteration is 497.7184513516806
# Cost of 45000 iteration is 497.7174210621772
# Cost of 45100 iteration is 497.7163908085571
# Cost of 45200 iteration is 497.7153605908188
# Cost of 45300 iteration is 497.7143304089604
# Cost of 45400 iteration is 497.71330026298034
# Cost of 45500 iteration is 497.7122701528771
# Cost of 45600 iteration is 497.71124007864825
# Cost of 45700 iteration is 497.71021004029313
# Cost of 45800 iteration is 497.70918003780855
# Cost of 45900 iteration is 497.70815007119455
# Cost of 46000 iteration is 497.7071201404489
# Cost of 46100 iteration is 497.7060902455689
# Cost of 46200 iteration is 497.7050603865545
# Cost of 46300 iteration is 497.70403056340217
# Cost of 46400 iteration is 497.7030007761122
# Cost of 46500 iteration is 497.7019710246808
# Cost of 46600 iteration is 497.7009413091074
# Cost of 46700 iteration is 497.6999116293917
# Cost of 46800 iteration is 497.6988819855295
# Cost of 46900 iteration is 497.6978523775208
# Cost of 47000 iteration is 497.6968228053624
# Cost of 47100 iteration is 497.69579326905443
# Cost of 47200 iteration is 497.69476376859365
# Cost of 47300 iteration is 497.69373430397843
# Cost of 47400 iteration is 497.692704875209
# Cost of 47500 iteration is 497.69167548228086
# Cost of 47600 iteration is 497.69064612519475
# Cost of 47700 iteration is 497.68961680394835
# Cost of 47800 iteration is 497.68858751853855
# Cost of 47900 iteration is 497.68755826896466
# Cost of 48000 iteration is 497.6865290552257
# Cost of 48100 iteration is 497.68549987731916
# Cost of 48200 iteration is 497.6844707352441
# Cost of 48300 iteration is 497.6834416289964
# Cost of 48400 iteration is 497.682412558578
# Cost of 48500 iteration is 497.6813835239848
# Cost of 48600 iteration is 497.6803545252162
# Cost of 48700 iteration is 497.6793255622694
# Cost of 48800 iteration is 497.67829663514345
# Cost of 48900 iteration is 497.67726774383596
# Cost of 49000 iteration is 497.67623888834675
# Cost of 49100 iteration is 497.6752100686728
# Cost of 49200 iteration is 497.67418128481285
# Cost of 49300 iteration is 497.67315253676526
# Cost of 49400 iteration is 497.67212382452846
# Cost of 49500 iteration is 497.67109514810056
# Cost of 49600 iteration is 497.6700665074798
# Cost of 49700 iteration is 497.66903790266406
# Cost of 49800 iteration is 497.66800933365266
# Cost of 49900 iteration is 497.66698080044364
# Cost of 50000 iteration is 497.6659523030345
# Cost of 50100 iteration is 497.6649238414239
# Cost of 50200 iteration is 497.66389541561074
# Cost of 50300 iteration is 497.6628670255932
# Cost of 50400 iteration is 497.66183867136914
# Cost of 50500 iteration is 497.6608103529374
# Cost of 50600 iteration is 497.6597820702956
# Cost of 50700 iteration is 497.6587538234426
# Cost of 50800 iteration is 497.65772561237617
# Cost of 50900 iteration is 497.6566974370955
# Cost of 51000 iteration is 497.655669297598
# Cost of 51100 iteration is 497.65464119388247
# Cost of 51200 iteration is 497.6536131259474
# Cost of 51300 iteration is 497.65258509378975
# Cost of 51400 iteration is 497.6515570974104
# Cost of 51500 iteration is 497.65052913680523
# Cost of 51600 iteration is 497.6495012119735
# Cost of 51700 iteration is 497.64847332291373
# Cost of 51800 iteration is 497.64744546962436
# Cost of 51900 iteration is 497.6464176521031
# Cost of 52000 iteration is 497.64538987034837
# Cost of 52100 iteration is 497.64436212435845
# Cost of 52200 iteration is 497.6433344141321
# Cost of 52300 iteration is 497.64230673966716
# Cost of 52400 iteration is 497.6412791009629
# Cost of 52500 iteration is 497.64025149801546
# Cost of 52600 iteration is 497.63922393082555
# Cost of 52700 iteration is 497.63819639939067
# Cost of 52800 iteration is 497.6371689037079
# Cost of 52900 iteration is 497.63614144377794
# Cost of 53000 iteration is 497.63511401959687
# Cost of 53100 iteration is 497.634086631164
# Cost of 53200 iteration is 497.6330592784777
# Cost of 53300 iteration is 497.63203196153626
# Cost of 53400 iteration is 497.63100468033804
# Cost of 53500 iteration is 497.6299774348802
# Cost of 53600 iteration is 497.6289502251623
# Cost of 53700 iteration is 497.62792305118336
# Cost of 53800 iteration is 497.62689591294003
# Cost of 53900 iteration is 497.62586881043165
# Cost of 54000 iteration is 497.6248417436554
# Cost of 54100 iteration is 497.6238147126109
# Cost of 54200 iteration is 497.6227877172962
# Cost of 54300 iteration is 497.6217607577088
# Cost of 54400 iteration is 497.62073383384796
# Cost of 54500 iteration is 497.6197069457121
# Cost of 54600 iteration is 497.61868009329817
# Cost of 54700 iteration is 497.617653276606
# Cost of 54800 iteration is 497.6166264956327
# Cost of 54900 iteration is 497.61559975037727
# Cost of 55000 iteration is 497.61457304083825
# Cost of 55100 iteration is 497.6135463670128
# Cost of 55200 iteration is 497.61251972890085
# Cost of 55300 iteration is 497.61149312649974
# Cost of 55400 iteration is 497.6104665598074
# Cost of 55500 iteration is 497.6094400288238
# Cost of 55600 iteration is 497.6084135335453
# Cost of 55700 iteration is 497.6073870739716
# Cost of 55800 iteration is 497.6063606500997
# Cost of 55900 iteration is 497.6053342619289
# Cost of 56000 iteration is 497.6043079094574
# Cost of 56100 iteration is 497.6032815926839
# Cost of 56200 iteration is 497.60225531160614
# Cost of 56300 iteration is 497.60122906622234
# Cost of 56400 iteration is 497.60020285653087
# Cost of 56500 iteration is 497.59917668252996
# Cost of 56600 iteration is 497.59815054421864
# Cost of 56700 iteration is 497.5971244415942
# Cost of 56800 iteration is 497.5960983746561
# Cost of 56900 iteration is 497.5950723434012
# Cost of 57000 iteration is 497.59404634782965
# Cost of 57100 iteration is 497.59302038793845
# Cost of 57200 iteration is 497.5919944637257
# Cost of 57300 iteration is 497.59096857519137
# Cost of 57400 iteration is 497.58994272233184
# Cost of 57500 iteration is 497.5889169051461
# Cost of 57600 iteration is 497.58789112363286
# Cost of 57700 iteration is 497.5868653777903
# Cost of 57800 iteration is 497.5858396676171
# Cost of 57900 iteration is 497.58481399311046
# Cost of 58000 iteration is 497.5837883542686
# Cost of 58100 iteration is 497.5827627510922
# Cost of 58200 iteration is 497.5817371835771
# Cost of 58300 iteration is 497.5807116517226
# Cost of 58400 iteration is 497.57968615552716
# Cost of 58500 iteration is 497.5786606949883
# Cost of 58600 iteration is 497.5776352701056
# Cost of 58700 iteration is 497.5766098808753
# Cost of 58800 iteration is 497.5755845272979
# Cost of 58900 iteration is 497.57455920937156
# Cost of 59000 iteration is 497.5735339270928
# Cost of 59100 iteration is 497.5725086804612
# Cost of 59200 iteration is 497.5714834694757
# Cost of 59300 iteration is 497.57045829413335
# Cost of 59400 iteration is 497.569433154433
# Cost of 59500 iteration is 497.56840805037257
# Cost of 59600 iteration is 497.5673829819513
# Cost of 59700 iteration is 497.5663579491669
# Cost of 59800 iteration is 497.56533295201746
# Cost of 59900 iteration is 497.5643079905021
# Cost of 60000 iteration is 497.56328306461745
# Cost of 60100 iteration is 497.5622581743639
# Cost of 60200 iteration is 497.5612333197388
# Cost of 60300 iteration is 497.5602085007409
# Cost of 60400 iteration is 497.5591837173675
# Cost of 60500 iteration is 497.55815896961724
# Cost of 60600 iteration is 497.5571342574895
# Cost of 60700 iteration is 497.5561095809816
# Cost of 60800 iteration is 497.5550849400927
# Cost of 60900 iteration is 497.55406033482
# Cost of 61000 iteration is 497.5530357651623
# Cost of 61100 iteration is 497.55201123111806
# Cost of 61200 iteration is 497.55098673268543
# Cost of 61300 iteration is 497.54996226986333
# Cost of 61400 iteration is 497.548937842649
# Cost of 61500 iteration is 497.5479134510411
# Cost of 61600 iteration is 497.54688909503875
# Cost of 61700 iteration is 497.54586477463977
# Cost of 61800 iteration is 497.5448404898417
# Cost of 61900 iteration is 497.5438162406444
# Cost of 62000 iteration is 497.54279202704424
# Cost of 62100 iteration is 497.5417678490414
# Cost of 62200 iteration is 497.540743706634
# Cost of 62300 iteration is 497.5397195998195
# Cost of 62400 iteration is 497.53869552859635
# Cost of 62500 iteration is 497.53767149296306
# Cost of 62600 iteration is 497.5366474929178
# Cost of 62700 iteration is 497.5356235284587
# Cost of 62800 iteration is 497.5345995995855
# Cost of 62900 iteration is 497.53357570629464
# Cost of 63000 iteration is 497.5325518485851
# Cost of 63100 iteration is 497.53152802645604
# Cost of 63200 iteration is 497.5305042399044
# Cost of 63300 iteration is 497.52948048892944
# Cost of 63400 iteration is 497.5284567735296
# Cost of 63500 iteration is 497.52743309370254
# Cost of 63600 iteration is 497.526409449447
# Cost of 63700 iteration is 497.52538584076126
# Cost of 63800 iteration is 497.5243622676433
# Cost of 63900 iteration is 497.52333873009167
# Cost of 64000 iteration is 497.52231522810433
# Cost of 64100 iteration is 497.52129176168063
# Cost of 64200 iteration is 497.5202683308182
# Cost of 64300 iteration is 497.5192449355148
# Cost of 64400 iteration is 497.5182215757705
# Cost of 64500 iteration is 497.51719825158193
# Cost of 64600 iteration is 497.51617496294773
# Cost of 64700 iteration is 497.51515170986664
# Cost of 64800 iteration is 497.5141284923373
# Cost of 64900 iteration is 497.51310531035654
# Cost of 65000 iteration is 497.5120821639238
# Cost of 65100 iteration is 497.5110590530376
# Cost of 65200 iteration is 497.510035977696
# Cost of 65300 iteration is 497.509012937897
# Cost of 65400 iteration is 497.50798993363964
# Cost of 65500 iteration is 497.5069669649214
# Cost of 65600 iteration is 497.5059440317414
# Cost of 65700 iteration is 497.5049211340974
# Cost of 65800 iteration is 497.50389827198757
# Cost of 65900 iteration is 497.5028754454109
# Cost of 66000 iteration is 497.5018526543653
# Cost of 66100 iteration is 497.50082989884885
# Cost of 66200 iteration is 497.4998071788606
# Cost of 66300 iteration is 497.4987844943987
# Cost of 66400 iteration is 497.49776184546096
# Cost of 66500 iteration is 497.49673923204557
# Cost of 66600 iteration is 497.4957166541509
# Cost of 66700 iteration is 497.49469411177625
# Cost of 66800 iteration is 497.4936716049199
# Cost of 66900 iteration is 497.4926491335785
# Cost of 67000 iteration is 497.49162669775177
# Cost of 67100 iteration is 497.4906042974377
# Cost of 67200 iteration is 497.4895819326352
# Cost of 67300 iteration is 497.4885596033422
# Cost of 67400 iteration is 497.4875373095554
# Cost of 67500 iteration is 497.48651505127566
# Cost of 67600 iteration is 497.48549282850087
# Cost of 67700 iteration is 497.48447064122786
# Cost of 67800 iteration is 497.48344848945567
# Cost of 67900 iteration is 497.48242637318293
# Cost of 68000 iteration is 497.48140429240755
# Cost of 68100 iteration is 497.48038224712934
# Cost of 68200 iteration is 497.4793602373435
# Cost of 68300 iteration is 497.4783382630513
# Cost of 68400 iteration is 497.47731632425024
# Cost of 68500 iteration is 497.47629442093756
# Cost of 68600 iteration is 497.47527255311354
# Cost of 68700 iteration is 497.4742507207747
# Cost of 68800 iteration is 497.47322892392026
# Cost of 68900 iteration is 497.4722071625484
# Cost of 69000 iteration is 497.47118543665715
# Cost of 69100 iteration is 497.4701637462458
# Cost of 69200 iteration is 497.46914209131126
# Cost of 69300 iteration is 497.4681204718524
# Cost of 69400 iteration is 497.4670988878683
# Cost of 69500 iteration is 497.46607733935645
# Cost of 69600 iteration is 497.46505582631534
# Cost of 69700 iteration is 497.4640343487432
# Cost of 69800 iteration is 497.4630129066393
# Cost of 69900 iteration is 497.4619915000007
# Cost of 70000 iteration is 497.460970128826
# Cost of 70100 iteration is 497.45994879311394
# Cost of 70200 iteration is 497.458927492863
# Cost of 70300 iteration is 497.45790622807147
# Cost of 70400 iteration is 497.45688499873654
# Cost of 70500 iteration is 497.4558638048578
# Cost of 70600 iteration is 497.45484264643284
# Cost of 70700 iteration is 497.4538215234603
# Cost of 70800 iteration is 497.45280043593846
# Cost of 70900 iteration is 497.45177938386587
# Cost of 71000 iteration is 497.45075836724067
# Cost of 71100 iteration is 497.44973738606114
# Cost of 71200 iteration is 497.44871644032594
# Cost of 71300 iteration is 497.4476955300334
# Cost of 71400 iteration is 497.44667465518063
# Cost of 71500 iteration is 497.44565381576734
# Cost of 71600 iteration is 497.44463301179144
# Cost of 71700 iteration is 497.4436122432518
# Cost of 71800 iteration is 497.4425915101456
# Cost of 71900 iteration is 497.44157081247124
# Cost of 72000 iteration is 497.4405501502284
# Cost of 72100 iteration is 497.4395295234146
# Cost of 72200 iteration is 497.43850893202796
# Cost of 72300 iteration is 497.437488376066
# Cost of 72400 iteration is 497.4364678555293
# Cost of 72500 iteration is 497.4354473704138
# Cost of 72600 iteration is 497.4344269207207
# Cost of 72700 iteration is 497.43340650644535
# Cost of 72800 iteration is 497.4323861275877
# Cost of 72900 iteration is 497.43136578414527
# Cost of 73000 iteration is 497.4303454761174
# Cost of 73100 iteration is 497.4293252035009
# Cost of 73200 iteration is 497.4283049662959
# Cost of 73300 iteration is 497.4272847644997
# Cost of 73400 iteration is 497.42626459811015
# Cost of 73500 iteration is 497.42524446712713
# Cost of 73600 iteration is 497.4242243715473
# Cost of 73700 iteration is 497.4232043113705
# Cost of 73800 iteration is 497.4221842865935
# Cost of 73900 iteration is 497.42116429721574
# Cost of 74000 iteration is 497.4201443432355
# Cost of 74100 iteration is 497.41912442465036
# Cost of 74200 iteration is 497.4181045414597
# Cost of 74300 iteration is 497.4170846936611
# Cost of 74400 iteration is 497.41606488125336
# Cost of 74500 iteration is 497.41504510423346
# Cost of 74600 iteration is 497.41402536260165
# Cost of 74700 iteration is 497.4130056563555
# Cost of 74800 iteration is 497.4119859854929
# Cost of 74900 iteration is 497.4109663500131
# Cost of 75000 iteration is 497.40994674991293
# Cost of 75100 iteration is 497.40892718519285
# Cost of 75200 iteration is 497.4079076558485
# Cost of 75300 iteration is 497.40688816188083
# Cost of 75400 iteration is 497.40586870328696
# Cost of 75500 iteration is 497.4048492800656
# Cost of 75600 iteration is 497.40382989221393
# Cost of 75700 iteration is 497.4028105397311
# Cost of 75800 iteration is 497.4017912226164
# Cost of 75900 iteration is 497.4007719408666
# Cost of 76000 iteration is 497.39975269448064
# Cost of 76100 iteration is 497.3987334834574
# Cost of 76200 iteration is 497.3977143077943
# Cost of 76300 iteration is 497.39669516749024
# Cost of 76400 iteration is 497.39567606254326
# Cost of 76500 iteration is 497.3946569929521
# Cost of 76600 iteration is 497.3936379587145
# Cost of 76700 iteration is 497.3926189598293
# Cost of 76800 iteration is 497.39159999629436
# Cost of 76900 iteration is 497.3905810681085
# Cost of 77000 iteration is 497.3895621752694
# Cost of 77100 iteration is 497.3885433177765
# Cost of 77200 iteration is 497.3875244956278
# Cost of 77300 iteration is 497.38650570882015
# Cost of 77400 iteration is 497.3854869573541
# Cost of 77500 iteration is 497.384468241226
# Cost of 77600 iteration is 497.38344956043585
# Cost of 77700 iteration is 497.3824309149804
# Cost of 77800 iteration is 497.38141230485957
# Cost of 77900 iteration is 497.3803937300703
# Cost of 78000 iteration is 497.37937519061256
# Cost of 78100 iteration is 497.37835668648273
# Cost of 78200 iteration is 497.3773382176806
# Cost of 78300 iteration is 497.3763197842038
# Cost of 78400 iteration is 497.37530138605064
# Cost of 78500 iteration is 497.37428302322013
# Cost of 78600 iteration is 497.3732646957095
# Cost of 78700 iteration is 497.372246403519
# Cost of 78800 iteration is 497.3712281466445
# Cost of 78900 iteration is 497.3702099250864
# Cost of 79000 iteration is 497.3691917388415
# Cost of 79100 iteration is 497.36817358790836
# Cost of 79200 iteration is 497.3671554722869
# Cost of 79300 iteration is 497.3661373919734
# Cost of 79400 iteration is 497.3651193469674
# Cost of 79500 iteration is 497.36410133726724
# Cost of 79600 iteration is 497.3630833628709
# Cost of 79700 iteration is 497.36206542377636
# Cost of 79800 iteration is 497.36104751998295
# Cost of 79900 iteration is 497.36002965148765
# Cost of 80000 iteration is 497.3590118182907
# Cost of 80100 iteration is 497.3579940203875
# Cost of 80200 iteration is 497.3569762577796
# Cost of 80300 iteration is 497.3559585304636
# Cost of 80400 iteration is 497.3549408384386
# Cost of 80500 iteration is 497.3539231817021
# Cost of 80600 iteration is 497.3529055602526
# Cost of 80700 iteration is 497.35188797408847
# Cost of 80800 iteration is 497.3508704232087
# Cost of 80900 iteration is 497.3498529076111
# Cost of 81000 iteration is 497.3488354272938
# Cost of 81100 iteration is 497.3478179822558
# Cost of 81200 iteration is 497.3468005724945
# Cost of 81300 iteration is 497.34578319800926
# Cost of 81400 iteration is 497.3447658587977
# Cost of 81500 iteration is 497.3437485548588
# Cost of 81600 iteration is 497.34273128618935
# Cost of 81700 iteration is 497.34171405279034
# Cost of 81800 iteration is 497.3406968546579
# Cost of 81900 iteration is 497.33967969179133
# Cost of 82000 iteration is 497.3386625641881
# Cost of 82100 iteration is 497.3376454718472
# Cost of 82200 iteration is 497.3366284147669
# Cost of 82300 iteration is 497.3356113929461
# Cost of 82400 iteration is 497.3345944063823
# Cost of 82500 iteration is 497.33357745507436
# Cost of 82600 iteration is 497.33256053901965
# Cost of 82700 iteration is 497.33154365821764
# Cost of 82800 iteration is 497.330526812666
# Cost of 82900 iteration is 497.3295100023637
# Cost of 83000 iteration is 497.3284932273091
# Cost of 83100 iteration is 497.3274764874992
# Cost of 83200 iteration is 497.3264597829331
# Cost of 83300 iteration is 497.32544311361033
# Cost of 83400 iteration is 497.3244264795278
# Cost of 83500 iteration is 497.3234098806841
# Cost of 83600 iteration is 497.3223933170784
# Cost of 83700 iteration is 497.3213767887071
# Cost of 83800 iteration is 497.3203602955706
# Cost of 83900 iteration is 497.31934383766617
# Cost of 84000 iteration is 497.3183274149926
# Cost of 84100 iteration is 497.31731102754776
# Cost of 84200 iteration is 497.3162946753315
# Cost of 84300 iteration is 497.31527835833964
# Cost of 84400 iteration is 497.3142620765721
# Cost of 84500 iteration is 497.31324583002686
# Cost of 84600 iteration is 497.3122296187025
# Cost of 84700 iteration is 497.31121344259685
# Cost of 84800 iteration is 497.310197301709
# Cost of 84900 iteration is 497.309181196037
# Cost of 85000 iteration is 497.30816512557885
# Cost of 85100 iteration is 497.3071490903325
# Cost of 85200 iteration is 497.30613309029735
# Cost of 85300 iteration is 497.3051171254719
# Cost of 85400 iteration is 497.3041011958529
# Cost of 85500 iteration is 497.30308530144055
# Cost of 85600 iteration is 497.30206944223187
# Cost of 85700 iteration is 497.3010536182252
# Cost of 85800 iteration is 497.30003782941947
# Cost of 85900 iteration is 497.29902207581347
# Cost of 86000 iteration is 497.29800635740446
# Cost of 86100 iteration is 497.29699067419176
# Cost of 86200 iteration is 497.2959750261724
# Cost of 86300 iteration is 497.2949594133461
# Cost of 86400 iteration is 497.2939438357106
# Cost of 86500 iteration is 497.29292829326346
# Cost of 86600 iteration is 497.2919127860044
# Cost of 86700 iteration is 497.29089731393105
# Cost of 86800 iteration is 497.2898818770423
# Cost of 86900 iteration is 497.28886647533625
# Cost of 87000 iteration is 497.2878511088109
# Cost of 87100 iteration is 497.286835777464
# Cost of 87200 iteration is 497.28582048129505
# Cost of 87300 iteration is 497.2848052203019
# Cost of 87400 iteration is 497.283789994483
# Cost of 87500 iteration is 497.28277480383684
# Cost of 87600 iteration is 497.2817596483614
# Cost of 87700 iteration is 497.28074452805504
# Cost of 87800 iteration is 497.2797294429169
# Cost of 87900 iteration is 497.2787143929445
# Cost of 88000 iteration is 497.2776993781364
# Cost of 88100 iteration is 497.27668439849083
# Cost of 88200 iteration is 497.2756694540058
# Cost of 88300 iteration is 497.27465454468006
# Cost of 88400 iteration is 497.27363967051286
# Cost of 88500 iteration is 497.27262483150065
# Cost of 88600 iteration is 497.27161002764325
# Cost of 88700 iteration is 497.27059525893856
# Cost of 88800 iteration is 497.2695805253842
# Cost of 88900 iteration is 497.26856582698025
# Cost of 89000 iteration is 497.26755116372374
# Cost of 89100 iteration is 497.26653653561215
# Cost of 89200 iteration is 497.26552194264633
# Cost of 89300 iteration is 497.26450738482237
# Cost of 89400 iteration is 497.26349286213997
# Cost of 89500 iteration is 497.26247837459675
# Cost of 89600 iteration is 497.26146392219135
# Cost of 89700 iteration is 497.2604495049219
# Cost of 89800 iteration is 497.25943512278707
# Cost of 89900 iteration is 497.2584207757849
# Cost of 90000 iteration is 497.2574064639139
# Cost of 90100 iteration is 497.25639218717293
# Cost of 90200 iteration is 497.2553779455588
# Cost of 90300 iteration is 497.2543637390711
# Cost of 90400 iteration is 497.25334956770814
# Cost of 90500 iteration is 497.2523354314678
# Cost of 90600 iteration is 497.2513213303483
# Cost of 90700 iteration is 497.2503072643491
# Cost of 90800 iteration is 497.24929323346737
# Cost of 90900 iteration is 497.24827923770147
# Cost of 91000 iteration is 497.24726527705053
# Cost of 91100 iteration is 497.24625135151274
# Cost of 91200 iteration is 497.2452374610863
# Cost of 91300 iteration is 497.244223605769
# Cost of 91400 iteration is 497.24320978555994
# Cost of 91500 iteration is 497.2421960004567
# Cost of 91600 iteration is 497.24118225045805
# Cost of 91700 iteration is 497.2401685355619
# Cost of 91800 iteration is 497.23915485576856
# Cost of 91900 iteration is 497.2381412110745
# Cost of 92000 iteration is 497.23712760147725
# Cost of 92100 iteration is 497.23611402697696
# Cost of 92200 iteration is 497.23510048757197
# Cost of 92300 iteration is 497.2340869832599
# Cost of 92400 iteration is 497.23307351403895
# Cost of 92500 iteration is 497.23206007990734
# Cost of 92600 iteration is 497.23104668086347
# Cost of 92700 iteration is 497.2300333169072
# Cost of 92800 iteration is 497.229019988035
# Cost of 92900 iteration is 497.228006694246
# Cost of 93000 iteration is 497.2269934355382
# Cost of 93100 iteration is 497.22598021191124
# Cost of 93200 iteration is 497.2249670233614
# Cost of 93300 iteration is 497.22395386988825
# Cost of 93400 iteration is 497.2229407514903
# Cost of 93500 iteration is 497.22192766816494
# Cost of 93600 iteration is 497.2209146199114
# Cost of 93700 iteration is 497.2199016067278
# Cost of 93800 iteration is 497.2188886286115
# Cost of 93900 iteration is 497.2178756855632
# Cost of 94000 iteration is 497.216862777579
# Cost of 94100 iteration is 497.2158499046584
# Cost of 94200 iteration is 497.21483706679913
# Cost of 94300 iteration is 497.2138242640002
# Cost of 94400 iteration is 497.21281149625946
# Cost of 94500 iteration is 497.21179876357525
# Cost of 94600 iteration is 497.2107860659462
# Cost of 94700 iteration is 497.20977340336947
# Cost of 94800 iteration is 497.2087607758453
# Cost of 94900 iteration is 497.2077481833715
# Cost of 95000 iteration is 497.20673562594544
# Cost of 95100 iteration is 497.20572310356584
# Cost of 95200 iteration is 497.2047106162327
# Cost of 95300 iteration is 497.20369816394236
# Cost of 95400 iteration is 497.20268574669296
# Cost of 95500 iteration is 497.20167336448446
# Cost of 95600 iteration is 497.20066101731413
# Cost of 95700 iteration is 497.1996487051805
# Cost of 95800 iteration is 497.1986364280825
# Cost of 95900 iteration is 497.1976241860181
# Cost of 96000 iteration is 497.1966119789853
# Cost of 96100 iteration is 497.195599806982
# Cost of 96200 iteration is 497.19458767000805
# Cost of 96300 iteration is 497.1935755680602
# Cost of 96400 iteration is 497.1925635011386
# Cost of 96500 iteration is 497.19155146924027
# Cost of 96600 iteration is 497.1905394723635
# Cost of 96700 iteration is 497.18952751050745
# Cost of 96800 iteration is 497.1885155836704
# Cost of 96900 iteration is 497.1875036918495
# Cost of 97000 iteration is 497.1864918350439
# Cost of 97100 iteration is 497.1854800132523
# Cost of 97200 iteration is 497.1844682264734
# Cost of 97300 iteration is 497.1834564747041
# Cost of 97400 iteration is 497.1824447579438
# Cost of 97500 iteration is 497.18143307619056
# Cost of 97600 iteration is 497.1804214294424
# Cost of 97700 iteration is 497.1794098176983
# Cost of 97800 iteration is 497.1783982409566
# Cost of 97900 iteration is 497.17738669921505
# Cost of 98000 iteration is 497.1763751924726
# Cost of 98100 iteration is 497.1753637207266
# Cost of 98200 iteration is 497.1743522839771
# Cost of 98300 iteration is 497.17334088222117
# Cost of 98400 iteration is 497.1723295154572
# Cost of 98500 iteration is 497.1713181836844
# Cost of 98600 iteration is 497.17030688689937
# Cost of 98700 iteration is 497.1692956251031
# Cost of 98800 iteration is 497.1682843982918
# Cost of 98900 iteration is 497.1672732064639
# Cost of 99000 iteration is 497.16626204961943
# Cost of 99100 iteration is 497.16525092775487
# Cost of 99200 iteration is 497.16423984086964
# Cost of 99300 iteration is 497.1632287889617
# Cost of 99400 iteration is 497.1622177720294
# Cost of 99500 iteration is 497.1612067900714
# Cost of 99600 iteration is 497.16019584308617
# Cost of 99700 iteration is 497.1591849310713
# Cost of 99800 iteration is 497.15817405402515
# Cost of 99900 iteration is 497.1571632119464

# %% [markdown]
# Lets define function of z-score

# %%
def zscore(x):
    mu = np.mean(x,axis=0) #mean
    sigma = np.std(x,axis=0) #standard deviation
    x_norm = (x-mu)/sigma
    return x_norm,mu,sigma

# %% [markdown]
# Compute the data with normalization

# %%
X_norm,mu,sigma = zscore(X_train)

fig, ax = plt.subplots(1,4,figsize=(12,3))
for i in range(len(X_features)):
    ax[i].scatter(X_norm[:,i],y_train)
    ax[i].set_xlabel(X_features[i])
ax[0].set_ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# Notice that before and after normalization graph looks similar but the axis varies

# %%
#After normalization we take learning as 0.1 and increase x3 to check the cost function variation

alpha = 0.1
w_norm = np.zeros(X_train.shape[1])
b_norm = 0.

for i in range(10000):
    if(i%100 == 0):
        print(f"Cost of {i} iteration is {compute_cost(X_norm,y_train,w_norm,b_norm )}")
    dw,db = gradient(X_norm,y_train,w_norm,b_norm )
    w_norm = w_norm-alpha*dw
    b_norm  = b_norm -alpha*db
# Out:
# Cost of 0 iteration is 71336.76233333333
# Cost of 100 iteration is 376.32203239328425
# Cost of 200 iteration is 373.98802236341567
# Cost of 300 iteration is 373.9829080023673
# Cost of 400 iteration is 373.98289664390154
# Cost of 500 iteration is 373.9828966186658
# Cost of 600 iteration is 373.98289661860997
# Cost of 700 iteration is 373.9828966186097
# Cost of 800 iteration is 373.98289661860974
# Cost of 900 iteration is 373.98289661860986
# Cost of 1000 iteration is 373.9828966186099
# Cost of 1100 iteration is 373.98289661860986
# Cost of 1200 iteration is 373.98289661860974
# Cost of 1300 iteration is 373.9828966186099
# Cost of 1400 iteration is 373.9828966186099
# Cost of 1500 iteration is 373.9828966186099
# Cost of 1600 iteration is 373.9828966186099
# Cost of 1700 iteration is 373.9828966186099
# Cost of 1800 iteration is 373.9828966186099
# Cost of 1900 iteration is 373.9828966186099
# Cost of 2000 iteration is 373.9828966186099
# Cost of 2100 iteration is 373.9828966186099
# Cost of 2200 iteration is 373.9828966186099
# Cost of 2300 iteration is 373.9828966186099
# Cost of 2400 iteration is 373.9828966186099
# Cost of 2500 iteration is 373.9828966186099
# Cost of 2600 iteration is 373.9828966186099
# Cost of 2700 iteration is 373.9828966186099
# Cost of 2800 iteration is 373.9828966186099
# Cost of 2900 iteration is 373.9828966186099
# Cost of 3000 iteration is 373.9828966186099
# Cost of 3100 iteration is 373.9828966186099
# Cost of 3200 iteration is 373.9828966186099
# Cost of 3300 iteration is 373.9828966186099
# Cost of 3400 iteration is 373.9828966186099
# Cost of 3500 iteration is 373.9828966186099
# Cost of 3600 iteration is 373.9828966186099
# Cost of 3700 iteration is 373.9828966186099
# Cost of 3800 iteration is 373.9828966186099
# Cost of 3900 iteration is 373.9828966186099
# Cost of 4000 iteration is 373.9828966186099
# Cost of 4100 iteration is 373.9828966186099
# Cost of 4200 iteration is 373.9828966186099
# Cost of 4300 iteration is 373.9828966186099
# Cost of 4400 iteration is 373.9828966186099
# Cost of 4500 iteration is 373.9828966186099
# Cost of 4600 iteration is 373.9828966186099
# Cost of 4700 iteration is 373.9828966186099
# Cost of 4800 iteration is 373.9828966186099
# Cost of 4900 iteration is 373.9828966186099
# Cost of 5000 iteration is 373.9828966186099
# Cost of 5100 iteration is 373.9828966186099
# Cost of 5200 iteration is 373.9828966186099
# Cost of 5300 iteration is 373.9828966186099
# Cost of 5400 iteration is 373.9828966186099
# Cost of 5500 iteration is 373.9828966186099
# Cost of 5600 iteration is 373.9828966186099
# Cost of 5700 iteration is 373.9828966186099
# Cost of 5800 iteration is 373.9828966186099
# Cost of 5900 iteration is 373.9828966186099
# Cost of 6000 iteration is 373.9828966186099
# Cost of 6100 iteration is 373.9828966186099
# Cost of 6200 iteration is 373.9828966186099
# Cost of 6300 iteration is 373.9828966186099
# Cost of 6400 iteration is 373.9828966186099
# Cost of 6500 iteration is 373.9828966186099
# Cost of 6600 iteration is 373.9828966186099
# Cost of 6700 iteration is 373.9828966186099
# Cost of 6800 iteration is 373.9828966186099
# Cost of 6900 iteration is 373.9828966186099
# Cost of 7000 iteration is 373.9828966186099
# Cost of 7100 iteration is 373.9828966186099
# Cost of 7200 iteration is 373.9828966186099
# Cost of 7300 iteration is 373.9828966186099
# Cost of 7400 iteration is 373.9828966186099
# Cost of 7500 iteration is 373.9828966186099
# Cost of 7600 iteration is 373.9828966186099
# Cost of 7700 iteration is 373.9828966186099
# Cost of 7800 iteration is 373.9828966186099
# Cost of 7900 iteration is 373.9828966186099
# Cost of 8000 iteration is 373.9828966186099
# Cost of 8100 iteration is 373.9828966186099
# Cost of 8200 iteration is 373.9828966186099
# Cost of 8300 iteration is 373.9828966186099
# Cost of 8400 iteration is 373.9828966186099
# Cost of 8500 iteration is 373.9828966186099
# Cost of 8600 iteration is 373.9828966186099
# Cost of 8700 iteration is 373.9828966186099
# Cost of 8800 iteration is 373.9828966186099
# Cost of 8900 iteration is 373.9828966186099
# Cost of 9000 iteration is 373.9828966186099
# Cost of 9100 iteration is 373.9828966186099
# Cost of 9200 iteration is 373.9828966186099
# Cost of 9300 iteration is 373.9828966186099
# Cost of 9400 iteration is 373.9828966186099
# Cost of 9500 iteration is 373.9828966186099
# Cost of 9600 iteration is 373.9828966186099
# Cost of 9700 iteration is 373.9828966186099
# Cost of 9800 iteration is 373.9828966186099
# Cost of 9900 iteration is 373.9828966186099

# %% [markdown]
# Before Scaling, Cost function value is 497..
# After Scaling, cost function value is 373...
#
# Same data but after normalization model works better as all the datapoints fit into similar range

# %% [markdown]
# Let's understand the terminology below and calculate scaled and unscaled prediction quality:
#
#
# **MAE (Mean Absolute Error)** — average size of the errors, ignoring direction (over/under prediction treated the same).
#
# $$MAE = \frac{1}{m} \sum_{i=1}^{m} \left| y^{(i)} - \hat{y}^{(i)} \right|$$
#
# **RMSE (Root Mean Squared Error)** — average error size, but squares errors first (so big misses are punished harder), then square-roots back to original units.
#
# $$RMSE = \sqrt{\frac{1}{m} \sum_{i=1}^{m} \left( y^{(i)} - \hat{y}^{(i)} \right)^2}$$
#
# **R² (R-squared / coefficient of determination)** — how much better the model is than just predicting the average every time. 1.0 = perfect, 0 = no better than guessing the mean.
#
# $$R^2 = 1 - \frac{\sum_{i=1}^{m} \left( y^{(i)} - \hat{y}^{(i)} \right)^2}{\sum_{i=1}^{m} \left( y^{(i)} - \bar{y} \right)^2}$$
#
# where $\hat{y}^{(i)}$ is the predicted value, $y^{(i)}$ is the actual value, and $\bar{y}$ is the mean of actual values.

# %%
def r_squared(y, y_pred):
    ss_res = np.sum((y - y_pred)**2)
    ss_tot = np.sum((y - np.mean(y))**2)
    return 1 - ss_res/ss_tot

def mae(y, y_pred):
    return np.mean(np.abs(y - y_pred))

def rmse(y, y_pred):
    return np.sqrt(np.mean((y - y_pred)**2))

# %%
pred_unscaled = X_train @ w_r + b_r
pred_scaled = X_norm @ w_norm + b_norm

# %% [markdown]
# **X_norm @ w_norm + b_norm — worked example**
#
# *(Illustrative numbers below, not the actual trained values from this notebook — just to show how the matrix multiply produces predictions.)*
#
# Say we have 3 houses, 2 features each (size_z, rooms_z — already z-scored).
#
# **X_norm** (3×2):
# ```
# [ 0.5, -1.0]
# [-1.0,  0.0]
# [ 1.2,  1.5]
# ```
#
# **w_norm** (2×1, learned weights — one per feature):
# ```
# [50000]
# [10000]
# ```
#
# **b_norm** (scalar): `300000`
#
# ---
#
# **Step 1 — X_norm @ w_norm**
#
# Each row does a dot product with w_norm:
#
# - Row 1: (0.5 × 50000) + (-1.0 × 10000) = 25000 − 10000 = **15000**
# - Row 2: (-1.0 × 50000) + (0.0 × 10000) = −50000 + 0 = **−50000**
# - Row 3: (1.2 × 50000) + (1.5 × 10000) = 60000 + 15000 = **75000**
#
# Result (3×1):
# ```
# [ 15000]
# [-50000]
# [ 75000]
# ```
#
# ---
#
# **Step 2 — add b_norm (300000) to every row**
#
# ```
# [315000]
# [250000]
# [375000]
# ```
#
# This final 3×1 vector **is** `pred_scaled` — one predicted price per house, in real dollars.
#
# ---
#
# Shape rule: `(m rows × n features) @ (n features × 1) = (m rows × 1)` — one prediction per row, no matter how many features you have.

# %%
print("Unscaled model:")
print("  R2:", r_squared(y_train, pred_unscaled))
print("  MAE:", mae(y_train, pred_unscaled))
print("  RMSE:", rmse(y_train, pred_unscaled))

print("Scaled model:")
print("  R2:", r_squared(y_train, pred_scaled))
print("  MAE:", mae(y_train, pred_scaled))
print("  RMSE:", rmse(y_train, pred_scaled))
# Out:
# Unscaled model:
#   R2: 0.9347512910192943
#   MAE: 24.553555586165814
#   RMSE: 31.532718005425252
# Scaled model:
#   R2: 0.9509170286494644
#   MAE: 22.674961445299356
#   RMSE: 27.348963293646424
